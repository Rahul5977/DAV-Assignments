# %%
import pandas as pd

# Load the Excel file
file_path = "Person_Data.xlsx"
df = pd.read_excel(file_path, sheet_name="Sheet1")

# Clean and organize the data into a dictionary {Person: Set of Attributes}
df_cleaned = df.drop(columns=["Sno"]).set_index("Person").stack().reset_index(drop=True, level=1)
df_cleaned = df_cleaned.groupby("Person").apply(set)

# Function to compute Jaccard distance
def jaccard_distance(set1, set2):
    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))
    return 1 - (intersection / union) if union != 0 else 1  # Handle empty sets




# Select two persons for comparison
person1 = "Dad"
person2 = "Dad"

set1 = df_cleaned.get(person1, set())
set2 = df_cleaned.get(person2, set())

# Compute Jaccard distance
jaccard_dist = jaccard_distance(set1, set2)

# Print results
print(f"Attributes of {person1}: {set1}")
print(f"Attributes of {person2}: {set2}")
print(f"Jaccard Distance between {person1} and {person2}: {jaccard_dist:.4f}")
# Out:
# Attributes of Dad: {'Honest', 'Loyal', 'Trustwarthy', 'Emotion less', 'Progressive Mind', 'Holy Person', 'Self Confidance', 'Hard working', 'Caring'}
# Attributes of Dad: {'Honest', 'Loyal', 'Trustwarthy', 'Emotion less', 'Progressive Mind', 'Holy Person', 'Self Confidance', 'Hard working', 'Caring'}
# Jaccard Distance between Dad and Dad: 0.0000

# %%
# jacard distance for each pair of words
person=list(df_cleaned.index)
for i in range(len(person)):
  for j in range(i+1,len(person)):
    set1 = df_cleaned.get(person[i], set())
    set2 = df_cleaned.get(person[j], set())
    jaccard_dist = jaccard_distance(set1, set2)
    print(f"Attributes of {person[i]}: {set1}")
    print(f"Attributes of {person[j]}: {set2}")
    print(f"Jaccard Distance between {person[i]} and {person[j]}: {jaccard_dist:.4f}")
    print('\n')
# Out:
# Streaming output truncated to the last 5000 lines.
# Attributes of A: {'Funny', 'Intellegent', 'Mature', 'Understanding', 'Courageous', 'Kind', 'Emotionaally Distant', 'Hard working', 'Caring', 'Ambitions', 'Short tempered'}
# Attributes of Saket: {'hypertrophy', 'destructive', 'socially dead', 'natural', 'bold', 'mental', 'hard working', 'Attractive', 'calm', 'fit', 'non controversial', 'strong', 'consistent'}
# Jaccard Distance between A and Saket: 1.0000
#
#
# Attributes of A: {'Funny', 'Intellegent', 'Mature', 'Understanding', 'Courageous', 'Kind', 'Emotionaally Distant', 'Hard working', 'Caring', 'Ambitions', 'Short tempered'}
# Attributes of Sashank: {'angry', 'humour', 'non vegetarian ', 'enjoyable', 'cool', 'hardworking', 'social'}
# Jaccard Distance between A and Sashank: 1.0000
#
#
# Attributes of A: {'Funny', 'Intellegent', 'Mature', 'Understanding', 'Courageous', 'Kind', 'Emotionaally Distant', 'Hard working', 'Caring', 'Ambitions', 'Short tempered'}
# Attributes of Saurav: {'gym', 'bulky body', 'gentle', 'funny', 'caring', 'expressive', 'traveling', 'cricket', 'table tennis', 'best friend', 'bargaining'}
# Jaccard Distance between A and Saurav: 1.0000
#
#
# Attributes of A: {'Funny', 'Intellegent', 'Mature', 'Understanding', 'Courageous', 'Kind', 'Emotionaally Distant', 'Hard working', 'Caring', 'Ambitions', 'Short tempered'}
# Attributes of Sreekar: {'6 feet', 'male', 'Likes Movies', 'Skill: Play with Keyboard', 'Likes Cricket', 'Fav Mov: Inception', 'Vijaywada AP', '65 kg', 'Reader'}
# Jaccard Distance between A and Sreekar: 1.0000
#
#
# Attributes of A: {'Funny', 'Intellegent', 'Mature', 'Understanding', 'Courageous', 'Kind', 'Emotionaally Distant', 'Hard working', 'Caring', 'Ambitions', 'Short tempered'}
# Attributes of Sudarshan: {'workout', 'male', 'good character', 'brown', '55 years'}
# Jaccard Distance between A and Sudarshan: 1.0000
#
#
# Attributes of A: {'Funny', 'Intellegent', 'Mature', 'Understanding', 'Courageous', 'Kind', 'Emotionaally Distant', 'Hard working', 'Caring', 'Ambitions', 'Short tempered'}
# Attributes of Sudeshna: {'confident', 'bold', 'short', 'fair', 'black eyes', 'movies', 'mature', 'childish', 'chill'}
# Jaccard Distance between A and Sudeshna: 1.0000
#
#
# Attributes of A: {'Funny', 'Intellegent', 'Mature', 'Understanding', 'Courageous', 'Kind', 'Emotionaally Distant', 'Hard working', 'Caring', 'Ambitions', 'Short tempered'}
# Attributes of Suresh: {'5.7 Height', '19 years old', 'Geedy about new thing', 'weight-62', 'Awareness', 'Overcomig failure', 'Male', 'Socialist'}
# Jaccard Distance between A and Suresh: 1.0000
#
#
# Attributes of A: {'Funny', 'Intellegent', 'Mature', 'Understanding', 'Courageous', 'Kind', 'Emotionaally Distant', 'Hard working', 'Caring', 'Ambitions', 'Short tempered'}
# Attributes of Theophila: {'reading', 'piano', 'coder', 'writing', 'friendly', 'singer'}
# Jaccard Distance between A and Theophila: 1.0000
#
#
# Attributes of A: {'Funny', 'Intellegent', 'Mature', 'Understanding', 'Courageous', 'Kind', 'Emotionaally Distant', 'Hard working', 'Caring', 'Ambitions', 'Short tempered'}
# Attributes of Varun: {'eye glasses', 'jolly', 'hard working', 'disciplined', 'determined', 'serious', 'physicque', 'gym', 'ignorant', 'kind', 'orthodox'}
# Jaccard Distance between A and Varun: 1.0000
#
#
# Attributes of A: {'Funny', 'Intellegent', 'Mature', 'Understanding', 'Courageous', 'Kind', 'Emotionaally Distant', 'Hard working', 'Caring', 'Ambitions', 'Short tempered'}
# Attributes of venkat: {'humour', 'non vegetarian ', 'happy', 'cool', 'hardworking', 'social'}
# Jaccard Distance between A and venkat: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of AB: {'Highly Intelligent', 'Bad at Sports', 'Lazy', 'Chill', 'Effortless', 'Intriguing', 'Communication'}
# Jaccard Distance between AA and AB: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of AD: {'very emotional', 'Funny', 'always panics', 'caring', 'shorter', 'Loving', 'smart', 'hardworking', 'curly hair', 'friendly', 'big eyes', 'multitasking'}
# Jaccard Distance between AA and AD: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of AE: {'foodie', 'coward', 'small', 'sister', 'cry often', 'painter', 'caring', 'mischievious', 'naughty', 'happy', 'girl', 'Sweet', 'loving', 'intelligent', 'cute', 'pretty'}
# Jaccard Distance between AA and AE: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of AF: {'humour', 'Short hair', 'lovable', 'confident', 'sports', 'lame', 'kind', 'Short'}
# Jaccard Distance between AA and AF: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of AH: {'Kind', 'funny', 'teddy bear', 'good character'}
# Jaccard Distance between AA and AH: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of AK: {'humour', 'decision making', 'knowledge', 'fearless', 'sketcher', 'beutiful', 'good dressing', 'emotional', 'Good cook', 'intelligent', 'strong', 'hairstylist', 'singer', 'introvert'}
# Jaccard Distance between AA and AK: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of AL: {'74 kg', 'leo', 'englandactor', 'Height 1.79 meter', 'brown', '41 years', 'white'}
# Jaccard Distance between AA and AL: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of Akash: {'21 Years Old', 'Slim', 'eye color: Brown', '5.7 height', 'Doing Engineering', '65 kg', 'Native Lang: Telgu', 'Color: Brown'}
# Jaccard Distance between AA and Akash: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of
 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of Nikhil: {'understanding', 'Politician', 'anime', 'shy', 'video game', 'fair', 'Occupation: Jila Sanyojak', 'thin', 'sports', 'drive', 'calm', 'sleepy', 'animal lover', 'artistic', 'introvert'}
# Jaccard Distance between AA and Nikhil: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of Prashant: {'flute', 'athletic', 'polite ', 'honest', 'lazy', 'sleepy', 'bhajan'}
# Jaccard Distance between AA and Prashant: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of Pratyush Kumar: {'Hero', 'funny', 'tempered', 'thin', 'Short'}
# Jaccard Distance between AA and Pratyush Kumar: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of Priyanshu: {'singing', 'big face', 'Small hair', 'helping nature', 'badminton', 'lazy', 'weak communication', 'cricket', 'white skin', 'driver', 'sport', 'fast thinking', 'introvert'}
# Jaccard Distance between AA and Priyanshu: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of Purna: {'newspaper', 'puntual', 'overthinker', 'teacher'}
# Jaccard Distance between AA and Purna: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of Radhika: {'friend', 'Beautiful', 'strength', 'caring', 'support', 'helping', 'motivator', 'patience', 'inspiring', 'best cook', 'sacrifice', 'hardworking', 'loving', 'strong'}
# Jaccard Distance between AA and Radhika: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of Rohit: {'standup comedian', 'Low Marks', 'Humorous', 'Casual in study', 'Professional ', 'Helpful', 'makes fun of everyone', 'shortcut study'}
# Jaccard Distance between AA and Rohit: 0.9167
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of SVS Rohit: {'humble', 'tall', 'disciplined', 'honest', 'calm', 'hardworking', 'kind'}
# Jaccard Distance between AA and SVS Rohit: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of Sachin Tendulkar: {'old', 'famous', 'short', 'fast', 'legendary'}
# Jaccard Distance between AA and Sachin Tendulkar: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of Saket: {'hypertrophy', 'destructive', 'socially dead', 'natural', 'bold', 'mental', 'hard working', 'Attractive', 'calm', 'fit', 'non controversial', 'strong', 'consistent'}
# Jaccard Distance between AA and Saket: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of Sashank: {'angry', 'humour', 'non vegetarian ', 'enjoyable', 'cool', 'hardworking', 'social'}
# Jaccard Distance between AA and Sashank: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of Saurav: {'gym', 'bulky body', 'gentle', 'funny', 'caring', 'expressive', 'traveling', 'cricket', 'table tennis', 'best friend', 'bargaining'}
# Jaccard Distance between AA and Saurav: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of Sreekar: {'6 feet', 'male', 'Likes Movies', 'Skill: Play with Keyboard', 'Likes Cricket', 'Fav Mov: Inception', 'Vijaywada AP', '65 kg', 'Reader'}
# Jaccard Distance between AA and Sreekar: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of Sudarshan: {'workout', 'male', 'good character', 'brown', '55 years'}
# Jaccard Distance between AA and Sudarshan: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of Sudeshna: {'confident', 'bold', 'short', 'fair', 'black eyes', 'movies', 'mature', 'childish', 'chill'}
# Jaccard Distance between AA and Sudeshna: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of Suresh: {'5.7 Height', '19 years old', 'Geedy about new thing', 'weight-62', 'Awareness', 'Overcomig failure', 'Male', 'Socialist'}
# Jaccard Distance between AA and Suresh: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of Theophila: {'reading', 'piano', 'coder', 'writing', 'friendly', 'singer'}
# Jaccard Distance between AA and Theophila: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of Varun: {'eye glasses', 'jolly', 'hard working', 'disciplined', 'determined', 'serious', 'physicque', 'gym', 'ignorant', 'kind', 'orthodox'}
# Jaccard Distance between AA and Varun: 1.0000
#
#
# Attributes of AA: {'Arrogant', 'Short temper', 'Overconfident', 'Hyper', 'Helpful'}
# Attributes of venkat: {'humour', 'non vegetarian ', 'happy', 'cool', 'hardworking', 'social'}
# Jaccard Distance between AA and venkat: 1.0000
#
#
# Attributes of AB: {'Highly Intelligent', 'Bad at Sports', 'Lazy', 'Chill', 'Effortless', 'Intriguing', 'Communication'}
# Attributes of AD: {'very emotional', 'Funny', 'always panics', 'caring', 'shorter', 'Loving', 'smart', 'hardworking', 'curly hair', 'friendly', 'big eyes', 'multitasking'}
# Jaccard Distance between AB and AD: 1.0000
#
#
# Attributes of AB: {'Highly Intelligent', 'Bad at Sports', 'Lazy', 'Chill', 'Effortless', 'Intriguing', 'Communication'}
# Attributes of AE: {'foodie', 'coward', 'small', 'sister', 'cry often', 'painter', 'caring', 'mischievious', 'naughty', 'happy', 'girl', 'Sweet', 'loving', 'intelligent', 'cute', 'pretty'}
# Jaccard Distance between AB and AE: 1.0000
#
#
# Attributes of AB: {'Highly Intelligent', 'Bad at Sports', 'Lazy', 'Chill', 'Effortless', 'Intriguing', 'Communication'}
# Attributes of AF: {'humour', 'Short hair', 'lovable', 'confident', 'sports', 'lame', 'kind', 'Short'}
# Jaccard Distance between AB and AF: 1.0000
#
#
# Attributes of AB: {'Highly Intelligent', 'Bad at Sports', 'Lazy', 'Chill', 'Effortless', 'Intriguing', 'Communication'}
# Attributes of AH: {'Kind', 'funny', 'teddy bear', 'good character'}
# Jaccard Distance between AB and AH: 1.0000
#
#
# Attributes of AB: {'Highly Intelligent', 'Bad at Sports', 'Lazy', 'Chill', 'Effortless', 'Intriguing', 'Communication'}
# Attributes of AK: {'humour', 'decision making', 'knowledge', 'fearless', 'sketcher', 'beutiful', 'good dressing', 'emotional', 'Good cook', 'intelligent', 'strong', 'hairstylist', 'singer', 'introvert'}
# Jaccard Distance between AB and AK: 1.0000
#
#
# Attributes of AB: {'Highly Intelligent', 'Bad at Sports', 'Lazy', 'Chill', 'Effortless', 'Intriguing', 'Communication'}
# Attributes of AL: {'74 kg', 'leo', 'englandactor', 'Height 1.79 meter', 'brown', '41 years', 'white'}
# Jaccard Distance between AB and AL: 1.0000
#
#
# Attributes of AB: {'Highly Intelligent', 'Bad at Sports', 'Lazy', 'Chill', 'Effortless', 'Intriguing', 'Communication'}
# Attributes of Akash: {'21 Years Old', 'Slim', 'eye color: Brown', '5.7 height', 'Doing Engineering', '65 kg', 'Native Lang: Telgu', 'Color: Brown'}
# Jaccard Distance between AB and Akash: 1.0000
#
#
# Attributes of AB: {'Highly Intelligent', 'Bad at Sports', 'Lazy', 'Chill', 'Effortless', 'Intriguing', 'Communication'}
# Attributes of Anil: {'Age: 20', 'Skin Color: Brown', 'Food: Biryani', 'Eye Color: Brown', 'Skill: Computer Language', '63 Kg', 'Hobbies: Football, Comics', '5.7 Feet', 'Movies: 99 Songs', 'Hair Color: Black', 'Male'}
# Jaccard Distance between AB and Anil: 1.0000
#
#
# Attributes of AB: {'Highly Intelligent', 'Bad at Sports', 'Lazy', 'Chill', 'Effortless', 'Intriguing', 'Communication'}
# Attributes of B: {'Writer', 'Intelligent', 'Honest', 'Funny', 'Slim', 'Loyal', 'Caring', 'Handsome', 'Voilent', 'Kind', 'Rich', 'Sportsman', 'Romantic'}
# Jaccard Distance between AB and B: 1.0000
#
#
# Attributes of AB: {'Highly Intelligent', 'Bad at Sports', 'Lazy', 'Chill', 'Effortless', 'Intriguing', 'Communication'}
# Attributes
1.0000
#
#
# Attributes of AE: {'foodie', 'coward', 'small', 'sister', 'cry often', 'painter', 'caring', 'mischievious', 'naughty', 'happy', 'girl', 'Sweet', 'loving', 'intelligent', 'cute', 'pretty'}
# Attributes of C: {'Helping', 'Funny', 'no emotions', 'Understanding', 'Smart', 'Supportive', 'Compromising', 'simple', 'Rich', 'selfless', 'agrees to everything', 'relational', 'Good Memory', 'reasonable'}
# Jaccard Distance between AE and C: 1.0000
#
#
# Attributes of AE: {'foodie', 'coward', 'small', 'sister', 'cry often', 'painter', 'caring', 'mischievious', 'naughty', 'happy', 'girl', 'Sweet', 'loving', 'intelligent', 'cute', 'pretty'}
# Attributes of D : {'Helping Nature', 'Foodie', 'Ignorance', 'Caring', 'Short tempered', 'Reader'}
# Jaccard Distance between AE and D : 1.0000
#
#
# Attributes of AE: {'foodie', 'coward', 'small', 'sister', 'cry often', 'painter', 'caring', 'mischievious', 'naughty', 'happy', 'girl', 'Sweet', 'loving', 'intelligent', 'cute', 'pretty'}
# Attributes of Dad: {'Honest', 'Loyal', 'Trustwarthy', 'Emotion less', 'Progressive Mind', 'Holy Person', 'Self Confidance', 'Hard working', 'Caring'}
# Jaccard Distance between AE and Dad: 1.0000
#
#
# ...
#
#
# Attributes of Sachin Tendulkar: {'old', 'famous', 'short', 'fast', 'legendary'}
# Attributes of Sreekar: {'6 feet', 'male', 'Likes Movies', 'Skill: Play with Keyboard', 'Likes Cricket', 'Fav Mov: Inception', 'Vijaywada AP', '65 kg', 'Reader'}
# Jaccard Distance between Sachin Tendulkar and Sreekar: 1.0000
#
#
# Attributes of Sachin Tendulkar: {'old', 'famous', 'short', 'fast', 'legendary'}
# Attributes of Sudarshan: {'workout', 'male', 'good character', 'brown', '55 years'}
# Jaccard Distance between Sachin Tendulkar and Sudarshan: 1.0000
#
#
# Attributes of Sachin Tendulkar: {'old', 'famous', 'short', 'fast', 'legendary'}
# Attributes of Sudeshna: {'confident', 'bold', 'short', 'fair', 'black eyes', 'movies', 'mature', 'childish', 'chill'}
# Jaccard Distance between Sachin Tendulkar and Sudeshna: 0.9231
#
#
# Attributes of Sachin Tendulkar: {'old', 'famous', 'short', 'fast', 'legendary'}
# Attributes of Suresh: {'5.7 Height', '19 years old', 'Geedy about new thing', 'weight-62', 'Awareness', 'Overcomig failure', 'Male', 'Socialist'}
# Jaccard Distance between Sachin Tendulkar and Suresh: 1.0000
#
#
# Attributes of Sachin Tendulkar: {'old', 'famous', 'short', 'fast', 'legendary'}
# Attributes of Theophila: {'reading', 'piano', 'coder', 'writing', 'friendly', 'singer'}
# Jaccard Distance between Sachin Tendulkar and Theophila: 1.0000
#
#
# Attributes of Sachin Tendulkar: {'old', 'famous', 'short', 'fast', 'legendary'}
# Attributes of Varun: {'eye glasses', 'jolly', 'hard working', 'disciplined', 'determined', 'serious', 'physicque', 'gym', 'ignorant', 'kind', 'orthodox'}
# Jaccard Distance between Sachin Tendulkar and Varun: 1.0000
#
#
# Attributes of Sachin Tendulkar: {'old', 'famous', 'short', 'fast', 'legendary'}
# Attributes of venkat: {'humour', 'non vegetarian ', 'happy', 'cool', 'hardworking', 'social'}
# Jaccard Distance between Sachin Tendulkar and venkat: 1.0000
#
#
# Attributes of Saket: {'hypertrophy', 'destructive', 'socially dead', 'natural', 'bold', 'mental', 'hard working', 'Attractive', 'calm', 'fit', 'non controversial', 'strong', 'consistent'}
# Attributes of Sashank: {'angry', 'humour', 'non vegetarian ', 'enjoyable', 'cool', 'hardworking', 'social'}
# Jaccard Distance between Saket and Sashank: 1.0000
#
#
# Attributes of Saket: {'hypertrophy', 'destructive', 'socially dead', 'natural', 'bold', 'mental', 'hard working', 'Attractive', 'calm', 'fit', 'non controversial', 'strong', 'consistent'}
# Attributes of Saurav: {'gym', 'bulky body', 'gentle', 'funny', 'caring', 'expressive', 'traveling', 'cricket', 'table tennis', 'best friend', 'bargaining'}
# Jaccard Distance between Saket and Saurav: 1.0000
#
#
# Attributes of Saket: {'hypertrophy', 'destructive', 'socially dead', 'natural', 'bold', 'mental', 'hard working', 'Attractive', 'calm', 'fit', 'non controversial', 'strong', 'consistent'}
# Attributes of Sreekar: {'6 feet', 'male', 'Likes Movies', 'Skill: Play with Keyboard', 'Likes Cricket', 'Fav Mov: Inception', 'Vijaywada AP', '65 kg', 'Reader'}
# Jaccard Distance between Saket and Sreekar: 1.0000
#
#
# Attributes of Saket: {'hypertrophy', 'destructive', 'socially dead', 'natural', 'bold', 'mental', 'hard working', 'Attractive', 'calm', 'fit', 'non controversial', 'strong', 'consistent'}
# Attributes of Sudarshan: {'workout', 'male', 'good character', 'brown', '55 years'}
# Jaccard Distance between Saket and Sudarshan: 1.0000
#
#
# Attributes of Saket: {'hypertrophy', 'destructive', 'socially dead', 'natural', 'bold', 'mental', 'hard working', 'Attractive', 'calm', 'fit', 'non controversial', 'strong', 'consistent'}
# Attributes of Sudeshna: {'confident', 'bold', 'short', 'fair', 'black eyes', 'movies', 'mature', 'childish', 'chill'}
# Jaccard Distance between Saket and Sudeshna: 0.9524
#
#
# Attributes of Saket: {'hypertrophy', 'destructive', 'socially dead', 'natural', 'bold', 'mental', 'hard working', 'Attractive', 'calm', 'fit', 'non controversial', 'strong', 'consistent'}
# Attributes of Suresh: {'5.7 Height', '19 years old', 'Geedy about new thing', 'weight-62', 'Awareness', 'Overcomig failure', 'Male', 'Socialist'}
# Jaccard Distance between Saket and Suresh: 1.0000
#
#
# Attributes of Saket: {'hypertrophy', 'destructive', 'socially dead', 'natural', 'bold', 'mental', 'hard working', 'Attractive', 'calm', 'fit', 'non controversial', 'strong', 'consistent'}
# Attributes of Theophila: {'reading', 'piano', 'coder', 'writing', 'friendly', 'singer'}
# Jaccard Distance between Saket and Theophila: 1.0000
#
#
# Attributes of Saket: {'hypertrophy', 'destructive', 'socially dead', 'natural', 'bold', 'mental', 'hard working', 'Attractive', 'calm', 'fit', 'non controversial', 'strong', 'consistent'}
# Attributes of Varun: {'eye glasses', 'jolly', 'hard working', 'disciplined', 'determined', 'serious', 'physicque', 'gym', 'ignorant', 'kind', 'orthodox'}
# Jaccard Distance between Saket and Varun: 0.9565
#
#
# Attributes of Saket: {'hypertrophy', 'destructive', 'socially dead', 'natural', 'bold', 'mental', 'hard working', 'Attractive', 'calm', 'fit', 'non controversial', 'strong', 'consistent'}
# Attributes of venkat: {'humour', 'non vegetarian ', 'happy', 'cool', 'hardworking', 'social'}
# Jaccard Distance between Saket and venkat: 1.0000
#
#
# Attributes of Sashank: {'angry', 'humour', 'non vegetarian ', 'enjoyable', 'cool', 'hardworking', 'social'}
# Attributes of Saurav: {'gym', 'bulky body', 'gentle', 'funny', 'caring', 'expressive', 'traveling', 'cricket', 'table tennis', 'best friend', 'bargaining'}
# Jaccard Distance between Sashank and Saurav: 1.0000
#
#
# Attributes of Sashank: {'angry', 'humour', 'non vegetarian ', 'enjoyable', 'cool', 'hardworking', 'social'}
# Attributes of Sreekar: {'6 feet', 'male', 'Likes Movies', 'Skill: Play with Keyboard', 'Likes Cricket', 'Fav Mov: Inception', 'Vijaywada AP', '65 kg', 'Reader'}
# Jaccard Distance between Sashank and Sreekar: 1.0000
#
#
# Attributes of Sashank: {'angry', 'humour', 'non vegetarian ', 'enjoyable', 'cool', 'hardworking', 'social'}
# Attributes of Sudarshan: {'workout', 'male', 'good character', 'brown', '55 years'}
# Jaccard Distance between Sashank and Sudarshan: 1.0000
#
#
# Attributes of Sashank: {'angry', 'humour', 'non vegetarian ', 'enjoyable', 'cool', 'hardworking', 'social'}
# Attributes of Sudeshna: {'confident', 'bold', 'short', 'fair', 'black eyes', 'movies', 'mature', 'childish', 'chill'}
# Jaccard Distance between Sashank and Sudeshna: 1.0000
#
#
# Attributes of Sashank: {'angry', 'humour', 'non vegetarian ', 'enjoyable', 'cool', 'hardworking', 'social'}
# Attributes of Suresh: {'5.7 Height', '19 years old', 'Geedy about new thing', 'weight-62', 'Awareness', 'Overcomig failure', 'Male', 'Socialist'}
# Jaccard Distance between Sashank and Suresh: 1.0000
#
#
# Attributes of Sashank: {'angry', 'humour', 'non vegetarian ', 'enjoyable', 'cool', 'hardworking', 'social'}
# Attributes of Theophila: {'reading', 'piano', 'coder', 'writing', 'friendly', 'singer'}
# Jaccard Distance between Sashank and Theophila: 1.0000
#
#
# Attributes of Sashank: {'angry', 'humour', 'non vegetarian ', 'enjoyable', 'cool', 'hardworking', 'social'}
# Attributes of Varun: {'eye glasses', 'jolly', 'hard working', 'disciplined', 'determined', 'serious', 'physicque', 'gym', 'ignorant', 'kind', 'orthodox'}
# Jaccard Distance between Sashank and Varun: 1.0000
#
#
# Attributes of Sashank: {'angry', 'humour', 'non vegetarian ', 'enjoyable', 'cool', 'hardworking', 'social'}
# Attributes of venkat: {'humour', 'non vegetarian ', 'happy', 'cool', 'hardworking', 'social'}
# Jaccard Distance between Sashank and venkat: 0.3750
#
#
# Attributes of Saurav: {'gym', 'bulky body', 'gentle', 'funny', 'caring', 'expressive', 'traveling', 'cricket', 'table tennis', 'best friend', 'bargaining'}
# Attributes of Sreekar: {'6 feet', 'male', 'Likes Movies', 'Skill: Play with Keyboard', 'Likes Cricket', 'Fav Mov: Inception', 'Vijaywada AP', '65 kg', 'Reader'}
# Jaccard Distance between Saurav and Sreekar: 1.0000
#
#
# Attributes of Saurav: {'gym', 'bulky body', 'gentle', 'funny', 'caring', 'expressive', 'traveling', 'cricket', 'table tennis', 'best friend', 'bargaining'}
# Attributes of Sudarshan: {'workout', 'male', 'good character', 'brown', '55 years'}
# Jaccard Distance between Saurav and Sudarshan: 1.0000
#
#
# Attributes of Saurav: {'gym', 'bulky body', 'gentle', 'funny', 'caring', 'expressive', 'traveling', 'cricket', 'table tennis', 'best friend', 'bargaining'}
# Attributes of Sudeshna: {'confident', 'bold', 'short', 'fair', 'black eyes', 'movies', 'mature', 'childish', 'chill'}
# Jaccard Distance between Saurav and Sudeshna: 1.0000
#
#
# Attributes of Saurav: {'gym', 'bulky body', 'gentle', 'funny', 'caring', 'expressive', 'traveling', 'cricket', 'table tennis', 'best friend', 'bargaining'}
# Attributes of Suresh: {'5.7 Height', '19 years old', 'Geedy about new thing', 'weight-62', 'Awareness', 'Overcomig failure', 'Male', 'Socialist'}
# Jaccard Distance between Saurav and Suresh: 1.0000
#
#
# Attributes of Saurav: {'gym', 'bulky body', 'gentle', 'funny', 'caring', 'expressive', 'traveling', 'cricket', 'table tennis', 'best friend', 'bargaining'}
# Attributes of Theophila: {'reading', 'piano', 'coder', 'writing', 'friendly', 'singer'}
# Jaccard Distance between Saurav and Theophila: 1.0000
#
#
# Attributes of Saurav: {'gym', 'bulky body', 'gentle', 'funny', 'caring', 'expressive', 'traveling', 'cricket', 'table tennis', 'best friend', 'bargaining'}
# Attributes of Varun: {'eye glasses', 'jolly', 'hard working', 'disciplined', 'determined', 'serious', 'physicque', 'gym', 'ignorant', 'kind', 'orthodox'}
# Jaccard Distance between Saurav and Varun: 0.9524
#
#
# Attributes of Saurav: {'gym', 'bulky body', 'gentle', 'funny', 'caring', 'expressive', 'traveling', 'cricket', 'table tennis', 'best friend', 'bargaining'}
# Attributes of venkat: {'humour', 'non vegetarian ', 'happy', 'cool', 'hardworking', 'social'}
# Jaccard Distance between Saurav and venkat: 1.0000
#
#
# Attributes of Sreekar: {'6 feet', 'male', 'Likes Movies', 'Skill: Play with Keyboard', 'Likes Cricket', 'Fav Mov: Inception', 'Vijaywada AP', '65 kg', 'Reader'}
# Attributes of Sudarshan: {'workout', 'male', 'good character', 'brown', '55 years'}
# Jaccard Distance between Sreekar and Sudarshan: 0.9231
#
#
# Attributes of Sreekar: {'6 feet', 'male', 'Likes Movies', 'Skill: Play with Keyboard', 'Likes Cricket', 'Fav Mov: Inception', 'Vijaywada AP', '65 kg', 'Reader'}
# Attributes of Sudeshna: {'confident', 'bold', 'short', 'fair', 'black eyes', 'movies', 'mature', 'childish', 'chill'}
# Jaccard Distance between Sreekar and Sudeshna: 1.0000
#
#
# Attributes of Sreekar: {'6 feet', 'male', 'Likes Movies', 'Skill: Play with Keyboard', 'Likes Cricket', 'Fav Mov: Inception', 'Vijaywada AP', '65 kg', 'Reader'}
# Attributes of Suresh: {'5.7 Height', '19 years old', 'Geedy about new thing', 'weight-62', 'Awareness', 'Overcomig failure', 'Male', 'Socialist'}
# Jaccard Distance between Sreekar and Suresh: 1.0000
#
#
# Attributes of Sreekar: {'6 feet', 'male', 'Likes Movies', 'Skill: Play with Keyboard', 'Likes Cricket', 'Fav Mov: Inception', 'Vijaywada AP', '65 kg', 'Reader'}
# Attributes of Theophila: {'reading', 'piano', 'coder', 'writing', 'friendly', 'singer'}
# Jaccard Distance between Sreekar and Theophila: 1.0000
#
#
# Attributes of Sreekar: {'6 feet', 'male', 'Likes Movies', 'Skill: Play with Keyboard', 'Likes Cricket', 'Fav Mov: Inception', 'Vijaywada AP', '65 kg', 'Reader'}
# Attributes of Varun: {'eye glasses', 'jolly', 'hard working', 'disciplined', 'determined', 'serious', 'physicque', 'gym', 'ignorant', 'kind', 'orthodox'}
# Jaccard Distance between Sreekar and Varun: 1.0000
#
#
# Attributes of Sreekar: {'6 feet', 'male', 'Likes Movies', 'Skill: Play with Keyboard', 'Likes Cricket', 'Fav Mov: Inception', 'Vijaywada AP', '65 kg', 'Reader'}
# Attributes of venkat: {'humour', 'non vegetarian ', 'happy', 'cool', 'hardworking', 'social'}
# Jaccard Distance between Sreekar and venkat: 1.0000
#
#
# Attributes of Sudarshan: {'workout', 'male', 'good character', 'brown', '55 years'}
# Attributes of Sudeshna: {'confident', 'bold', 'short', 'fair', 'black eyes', 'movies', 'mature', 'childish', 'chill'}
# Jaccard Distance between Sudarshan and Sudeshna: 1.0000
#
#
# Attributes of Sudarshan: {'workout', 'male', 'good character', 'brown', '55 years'}
# Attributes of Suresh: {'5.7 Height', '19 years old', 'Geedy about new thing', 'weight-62', 'Awareness', 'Overcomig failure', 'Male', 'Socialist'}
# Jaccard Distance between Sudarshan and Suresh: 1.0000
#
#
# Attributes of Sudarshan: {'workout', 'male', 'good character', 'brown', '55 years'}
# Attributes of Theophila: {'reading', 'piano', 'coder', 'writing', 'friendly', 'singer'}
# Jaccard Distance between Sudarshan and Theophila: 1.0000
#
#
# Attributes of Sudarshan: {'workout', 'male', 'good character', 'brown', '55 years'}
# Attributes of Varun: {'eye glasses', 'jolly', 'hard working', 'disciplined', 'determined', 'serious', 'physicque', 'gym', 'ignorant', 'kind', 'orthodox'}
# Jaccard Distance between Sudarshan and Varun: 1.0000
#
#
# Attributes of Sudarshan: {'workout', 'male', 'good character', 'brown', '55 years'}
# Attributes of venkat: {'humour', 'non vegetarian ', 'happy', 'cool', 'hardworking', 'social'}
# Jaccard Distance between Sudarshan and venkat: 1.0000
#
#
# Attributes of Sudeshna: {'confident', 'bold', 'short', 'fair', 'black eyes', 'movies', 'mature', 'childish', 'chill'}
# Attributes of Suresh: {'5.7 Height', '19 years old', 'Geedy about new thing', 'weight-62', 'Awareness', 'Overcomig failure', 'Male', 'Socialist'}
# Jaccard Distance between Sudeshna and Suresh: 1.0000
#
#
# Attributes of Sudeshna: {'confident', 'bold', 'short', 'fair', 'black eyes', 'movies', 'mature', 'childish', 'chill'}
# Attributes of Theophila: {'reading', 'piano', 'coder', 'writing', 'friendly', 'singer'}
# Jaccard Distance between Sudeshna and Theophila: 1.0000
#
#
# Attributes of Sudeshna: {'confident', 'bold', 'short', 'fair', 'black eyes', 'movies', 'mature', 'childish', 'chill'}
# Attributes of Varun: {'eye glasses', 'jolly', 'hard working', 'disciplined', 'determined', 'serious', 'physicque', 'gym', 'ignorant', 'kind', 'orthodox'}
# Jaccard Distance between Sudeshna and Varun: 1.0000
#
#
# Attributes of Sudeshna: {'confident', 'bold', 'short', 'fair', 'black eyes', 'movies', 'mature', 'childish', 'chill'}
# Attributes of venkat: {'humour', 'non vegetarian ', 'happy', 'cool', 'hardworking', 'social'}
# Jaccard Distance between Sudeshna and venkat: 1.0000
#
#
# Attributes of Suresh: {'5.7 Height', '19 years old', 'Geedy about new thing', 'weight-62', 'Awareness', 'Overcomig failure', 'Male', 'Socialist'}
# Attributes of Theophila: {'reading', 'piano', 'coder', 'writing', 'friendly', 'singer'}
# Jaccard Distance between Suresh and Theophila: 1.0000
#
#
# Attributes of Suresh: {'5.7 Height', '19 years old', 'Geedy about new thing', 'weight-62', 'Awareness', 'Overcomig failure', 'Male', 'Socialist'}
# Attributes of Varun: {'eye glasses', 'jolly', 'hard working', 'disciplined', 'determined', 'serious', 'physicque', 'gym', 'ignorant', 'kind', 'orthodox'}
# Jaccard Distance between Suresh and Varun: 1.0000
#
#
# Attributes of Suresh: {'5.7 Height', '19 years old', 'Geedy about new thing', 'weight-62', 'Awareness', 'Overcomig failure', 'Male', 'Socialist'}
# Attributes of venkat: {'humour', 'non vegetarian ', 'happy', 'cool', 'hardworking', 'social'}
# Jaccard Distance between Suresh and venkat: 1.0000
#
#
# Attributes of Theophila: {'reading', 'piano', 'coder', 'writing', 'friendly', 'singer'}
# Attributes of Varun: {'eye glasses', 'jolly', 'hard working', 'disciplined', 'determined', 'serious', 'physicque', 'gym', 'ignorant', 'kind', 'orthodox'}
# Jaccard Distance between Theophila and Varun: 1.0000
#
#
# Attributes of Theophila: {'reading', 'piano', 'coder', 'writing', 'friendly', 'singer'}
# Attributes of venkat: {'humour', 'non vegetarian ', 'happy', 'cool', 'hardworking', 'social'}
# Jaccard Distance between Theophila and venkat: 1.0000
#
#
# Attributes of Varun: {'eye glasses', 'jolly', 'hard working', 'disciplined', 'determined', 'serious', 'physicque', 'gym', 'ignorant', 'kind', 'orthodox'}
# Attributes of venkat: {'humour', 'non vegetarian ', 'happy', 'cool', 'hardworking', 'social'}
# Jaccard Distance between Varun and venkat: 1.0000

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import jaccard_score
from itertools import combinations

# Sample binary data (replace with your actual data)
data = np.random.randint(2, size=(10, 5))  # 10 samples, 5 features

# Calculate pairwise Jaccard distances
distances = []
for (i, j) in combinations(range(data.shape[0]), 2):
    dist = 1 - jaccard_score(data[i], data[j])  # Jaccard distance is 1 - Jaccard similarity
    distances.append(dist)

# Define distance thresholds (e.g., from 0 to 1 in steps of 0.05)
thresholds = np.arange(0, 1.05, 0.05)

# Calculate the percentage of pairs within each threshold
percentages = []
for threshold in thresholds:
    count = sum(1 for d in distances if d <= threshold)
    percentage = (count / len(distances)) * 100
    percentages.append(percentage)

# Plot the results
plt.plot(thresholds, percentages, marker='o')
plt.xlabel('Jaccard Distance Threshold')
plt.ylabel('Percentage of Pairs Within Threshold (%)')
plt.title('Percentage of Pairs Within Jaccard Distance Threshold')
plt.grid(True)
plt.show()

# %%
# Define distance thresholds (e.g., from 0 to 1 in steps of 0.05)
thresholds = np.arange(0, 1.05, 0.05)

# Calculate the percentage of pairs within each threshold
percentages = []
for threshold in thresholds:
    count = sum(1 for d in distances if d <= threshold)
    percentage = (count / len(distances)) * 100
    percentages.append(percentage)

# Plot the results as a histogram
plt.figure(figsize=(10, 6))
plt.hist(distances, bins=thresholds, edgecolor='black')
plt.xlabel('Jaccard Distance')
plt.ylabel('Percentage of Pairs')
plt.title('Histogram of Jaccard Distances')
plt.xticks(thresholds)  # Set x-axis ticks to the thresholds
plt.grid(True, axis='y') # Add gridlines only to the y-axis for better visualization
plt.show()
